# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/test/blob/main/NB_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=c51a95bc1c34702f47deacb7b66da2b280f75b50fc3c18fb110316f9471609e0
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %%
from pandasql import sqldf

# %%
# !pip install pandasql

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
type('perro')
# Out:
# str

# %%
path_github = 'https://raw.githubusercontent.com/alexandergribenchenko/test/main/ml_project1_data.csv'

# %%
path_github
# Out:
# 'https://raw.githubusercontent.com/alexandergribenchenko/test/main/ml_project1_data.csv'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df = pd.read_csv(path_github)
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
df.Response.value_counts(normalize=True)
# Out:
# Response
# 0    0.850893
# 1    0.149107
# Name: proportion, dtype: float64

# %%
sqldf("""
SELECT *
FROM df
WHERE ID = 10870
""")
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  10870        1967  Graduation        Married  61223.0        0         1
#
#   Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  2013-06-13       46       709         43              182               42
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0               118           247                  2                9
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0                    3                  4                  5             0
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# 0             0             0             0             0         0
#
#    Z_CostContact  Z_Revenue  Response
# 0              3         11         0

# %%
clientes_por_categoria = df['Marital_Status'].value_counts().reset_index()
clientes_por_categoria.columns = ['Marital_Status', 'Num_Clientes']

# Calcular el porcentaje de cada categoría con respecto al total de clientes
clientes_por_categoria['Porcentaje'] = (clientes_por_categoria['Num_Clientes'] / len(df)) * 100.0

# Ordenar los resultados de mayor a menor según el número de clientes
clientes_por_categoria = clientes_por_categoria.sort_values(by='Num_Clientes', ascending=False)
clientes_por_categoria
# Out:
#   Marital_Status  Num_Clientes  Porcentaje
# 0        Married           864   38.571429
# 1       Together           580   25.892857
# 2         Single           480   21.428571
# 3       Divorced           232   10.357143
# 4          Widow            77    3.437500
# 5          Alone             3    0.133929
# 6         Absurd             2    0.089286
# 7           YOLO             2    0.089286

# %% [markdown]
# # 1. Cuanto?
#
# La cantidad de

# %%
sqldf("""
SELECT Marital_Status,
  COUNT(ID) AS Num_Clientes,
  COUNT(ID) * 100.0 / SUM(COUNT(ID)) OVER () AS Porcentaje
FROM df
GROUP BY Marital_Status
ORDER BY Num_Clientes DESC;
""")
# Out:
#   Marital_Status  Num_Clientes  Porcentaje
# 0        Married           864   38.571429
# 1       Together           580   25.892857
# 2         Single           480   21.428571
# 3       Divorced           232   10.357143
# 4          Widow            77    3.437500
# 5          Alone             3    0.133929
# 6         Absurd             2    0.089286
# 7           YOLO             2    0.089286

# %%
sqldf("""
SELECT COUNT(id)
FROM df
WHERE Marital_Status = 'Single'
""")
# Out:
#    COUNT(id)
# 0        480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.Marital_Status.unique()
# Out:
# array(['Single', 'Together', 'Married', 'Divorced', 'Widow', 'Alone',
#        'Absurd', 'YOLO'], dtype=object)

# %%
df.Marital_Status.value_counts(normalize=True)
# Out:
# Marital_Status
# Married     0.385714
# Together    0.258929
# Single      0.214286
# Divorced    0.103571
# Widow       0.034375
# Alone       0.001339
# Absurd      0.000893
# YOLO        0.000893
# Name: proportion, dtype: float64

# %%
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
2+2
# Out:
# 4
